# %%
import reconstruction
import MicFileTool
import numpy as np
import matplotlib.pyplot as plt
import IntBin
import pickle

# %%
# integrate binary
output='/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'
ImagePar={'nDetectors':4,
        'sBinFilePrefix':'/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_',
        'nReductionNSUM':4,
        'nBinFileIndexStart':0,
        'fOmegaStart':-90,
        'fOmegaStop':90,
        }
IntBin.IntegrateBinFiles(ImagePar,output)
# Out:
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000001.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000002.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000003.bin0
# Writing: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000004.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000005.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000006.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced/Au_johnson_aug18_z0_000007.bin0
# Writing: /home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_000001.bin0
# ...

# %% [markdown]
# # manual etstimation of parameters
# ## center gold
# ### 5mm:
# #### J:1024,1058, j_avg = 1041
# #### K: 2017
# ### 7mm:
# #### J:1007,1040, j_avg = 1023.5
# #### K: 2013
# ### 9mm:
# #### J: 993, 1021, j_avg = 1007
# #### K: 2007
# ### 11mm:
# #### J:974, 1007, j_avg = 990.5
# #### K:2003
# ### 13mm:
# #### J:958, 992, j_avg = 975
# #### K: 1996

# %%
# see only one grain, so refine with phase0:

# prepare reconstructor, load in data
S = reconstruction.Reconstructor_GPU()

centerL = np.array([[4.63765, 6.63765]])
centerJ = np.array([[2047-1041, 2047-1023.5]])
centerK = np.array([[2017, 2013]])
centerRot = np.array([[[89.7649212,  90.16326194,  0.10614946],
                       [89.54845716, 90.48912137, -0.48860496]]])
S.set_det_param(centerL, centerJ, centerK, centerRot)

S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('gold')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.002,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug17_50x50_0.025_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True
# Out:
# (256, 3)
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
S.serial_recon_multi_stage()
# Out:
# ==========start of reconstruction========
#
# voxelIdx: 214, max hitratio: 0.12765957415103912, peakcnt: 47,reconstructed euler angle [ 40.64727818  37.6839705  348.64984807]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8a2259192a94> in <module>()
# ----> 1 S.serial_recon_multi_stage()
#
# ~/work/suter_aug18/g-force/reconstruction.py in serial_recon_multi_stage(self)
#    1914             # start of simulation
#    1915             voxelIdx = random.choice(self.voxelIdxStage0)
# -> 1916             self.single_voxel_recon(voxelIdx, self.afFZMatD,self.searchBatchSize)
#    1917             if self.voxelHitRatio[voxelIdx] > self.floodFillStartThreshold:
#    1918                 self.flood_fill(voxelIdx)
#
# ~/work/suter_aug18/g-force/reconstruction.py in single_voxel_recon(self, voxelIdx, afFZMatD, NSearchOrien, NIteration, BoundStart)
# ...

# %%
# see only one grain, so refine with phase0:

# prepare reconstructor, load in data
S = reconstruction.Reconstructor_GPU()
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('gold')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.002,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug17_50x50_0.025_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True
# Out:
# (256, 3)
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
# blind search for parameters
# find approximate parameter first, after maxhitratio mostly above 0.65, can move to the next phase
centerL, centerJ, centerK, centerRot = S.geo_opt_phase_0(rotOptimization=True)
# Out:
#  new parameters: [[1017.6638176  1017.52745396]], [[2013.45029242 2013.33124479]], [[5.14745305 7.14745305]], max hitratio:0.04651162773370743, rangeL:1.7, rangeJ:170.0, rangeK:85.0
#  new parameters: [[1019.88120889 1019.23484522]], [[2019.38052527 2019.20481098]], [[5.01440958 7.01440958]], max hitratio:0.06666667014360428, rangeL:1.4449999999999998, rangeJ:144.5, rangeK:72.25
#  new parameters: [[1016.80674074 1016.16037707]], [[2023.2338588 2022.7370334]], [[4.96409398 6.96409398]], max hitratio:0.1111111119389534, rangeL:1.2282499999999998, rangeJ:122.825, rangeK:61.4125
#  new parameters: [[1012.1028044  1012.43904078]], [[2025.14446998 2024.24712828]], [[4.88348228 6.88348228]], max hitratio:0.1304347813129425, rangeL:1.0440124999999998, rangeJ:104.40125, rangeK:52.200625
# ...

# %%
'''
[[4.58029824 6.58029824]] [[1019.85202638 1024.74226784]] [[2018.59988031 2013.40010482]] [[[90.82665396 91.0619491  -0.51502002]
  [89.87588516 90.86501845 -0.52827803]]]
 '''
centerL = np.array([[4.58029824, 6.58029824]])
centerJ = np.array([[1019.85202638, 1024.74226784]])
centerK = np.array([[2018.59988031, 2013.40010482]])
centerRot = np.array([[[90.82665396, 91.0619491,  -0.51502002],
  [89.87588516, 90.86501845, -0.52827803]]])

# see only one grain, so refine with phase0:

# prepare reconstructor, load in data
S = reconstruction.Reconstructor_GPU()

S.set_det_param(centerL, centerJ, centerK, centerRot)

S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('gold')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.002,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug17_50x50_0.025_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True


S.serial_recon_multi_stage()
# Out:
# (256, 3)
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
MicFileTool.plot_square_mic(S.squareMicData,0.3)

# %%
S.geo_opt_phase_0(S.squareMicData[:,:,6]>0.3,centerL=centerL, centerJ=centerJ, centerK=centerK, centerRot=centerRot,
                        rangeL=0.5, rangeJ=10, rangeK=5, rangeRot=None,
                        rotOptimization=True)
# Out:
#  new parameters: [[1023.98914212 1033.47512843]], [[2020.26654698 2016.48343811]], [[4.60445283 6.60445283]], max hitratio:0.3478260934352875, rangeL:0.425, rangeJ:8.500000000000048, rangeK:4.25
#  new parameters: [[1025.43595066 1041.43257525]], [[2020.91761083 2017.478119  ]], [[4.57732517 6.57732517]], max hitratio:0.45652174949645996, rangeL:0.36124999999999996, rangeJ:7.2250000000000405, rangeK:3.6125
#  new parameters: [[1022.99751316 1036.59605268]], [[2019.07292998 2016.44625065]], [[4.57732517 6.57732517]], max hitratio:0.5531914830207825, rangeL:0.30706249999999996, rangeJ:6.141250000000034, rangeK:3.0706249999999997
#  new parameters: [[1026.5799091  1043.00081041]], [[2019.72625445 2017.09957512]], [[4.54022178 6.54022178]], max hitratio:0.75, rangeL:0.26100312499999995, rangeJ:5.2200625000000285, rangeK:2.6100312499999996
# ...

# %%
centerL = np.array([[4.5119044, 6.5119044]])
centerJ = np.array([[1016.8313418 , 1029.44074923]])
centerK = np.array([[2015.08026123, 2011.5392429 ]])
centerRot = np.array([[[89.52662997, 90.54081701, -0.2588201 ],
         [89.80620059, 89.80781596,  0.1010359 ]]])
centerL, centerJ, centerK, centerRot = S.geo_opt_phase_0(S.squareMicData[:,:,6]>0.3,centerL=centerL, centerJ=centerJ, centerK=centerK, centerRot=centerRot,
                        rangeL=0.5, rangeJ=10, rangeK=5, rangeRot=None,
                        rotOptimization=True)
# Out:
#  new parameters: [[1010.07208276 1022.68149019]], [[2017.64970574 2014.83209164]], [[4.56745996 6.56745996]], max hitratio:0.7021276354789734, rangeL:0.425, rangeJ:8.5, rangeK:4.25
#  new parameters: [[1008.84229557 1021.451703  ]], [[2018.87949293 2016.06187883]], [[4.56745996 6.56745996]], max hitratio:0.75, rangeL:0.36124999999999996, rangeJ:7.225, rangeK:3.6125
#  new parameters: [[1014.71260807 1033.14717162]], [[2019.3461075 2016.5284934]], [[4.56745996 6.56745996]], max hitratio:0.8958333134651184, rangeL:0.30706249999999996, rangeJ:6.141249999999999, rangeK:3.0706249999999997
#  new parameters: [[1012.05139964 1028.60438873]], [[2017.71279634 2014.89518224]], [[4.56745996 6.56745996]], max hitratio:0.4893617033958435, rangeL:0.26100312499999995, rangeJ:5.220062499999999, rangeK:2.6100312499999996
# ...

# %%
S.set_det_param(centerL, centerJ, centerK, centerRot)

S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('gold')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.002,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug17_50x50_0.025_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True


S.serial_recon_multi_stage()
# Out:
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
MicFileTool.plot_square_mic(S.squareMicData,0.3)

# %%
plt.imshow(S.squareMicData[:,:,6].T, origin='lower')
plt.colorbar()

# %%
# integrate binary
output='/home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_'
ImagePar={'nDetectors':4,
        'sBinFilePrefix':'/home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_',
        'nReductionNSUM':4,
        'nBinFileIndexStart':0,
        'fOmegaStart':-90,
        'fOmegaStop':90,
        }
IntBin.IntegrateBinFiles(ImagePar,output)
# Out:
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000001.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000002.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000003.bin0
# Writing: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000004.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000005.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000006.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced/SA1_test1_z0_000007.bin0
# Writing: /home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_000001.bin0
# ...

# %%
import pickle
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
save_object((centerL, centerJ, centerK, centerRot),'geometry.p')

# %%
with open('geometry.p', 'rb') as input:
    centerL, centerJ, centerK, centerRot  = pickle.load(input)
S = reconstruction.Reconstructor_GPU()
S.set_det_param(centerL, centerJ, centerK, centerRot)
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('stainless_steel')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.02,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Iron_SA1_johnson_aug17_50x50_0.02_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True
S.serial_recon_multi_stage()
# Out:
# (256, 3)
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
#continue optimize parameters
with open('geometry_run2_0.91.p', 'rb') as input:
    centerL, centerJ, centerK, centerRot  = pickle.load(input)
S = reconstruction.Reconstructor_GPU()
S.set_det_param(centerL, centerJ, centerK, centerRot)
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('gold')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/Au_reduced_1degree/Au_int_1degree_suter_aug18_z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([50,50],voxelsize=0.001,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug17_50x50_0.025_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True

centerL, centerJ, centerK, centerRot = S.geo_opt_phase_0(S.squareMicData[:,:,6]>0.3,centerL=centerL, centerJ=centerJ, centerK=centerK, centerRot=centerRot,
                        rangeL=0.05, rangeJ=10, rangeK=5, rangeRot=None,
                        rotOptimization=True,update_threshold=0.9,relativeL=0.01,relativeJ=5, relativeK=2,rate=1,NIteration=20)

S.set_Q(7)
S.create_square_mic([10,10],voxelsize=0.005,shift=[0,0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug18_10x10_0.005_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 5000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)   
aIdxVoxel = S.geo_opt_phase_1(centerL, centerJ, centerK, centerRot)
S.save_square_mic('geo_opt_test.npy')

misOrienTmp = S.get_misorien_map(S.accMat)
grainBoundaryMask = misOrienTmp>0.1
#grainBoundary = ndi.maximum_filter(grainBoundary,size=3)
conf = S.squareMicData[:,:,6]
boundaryConf = conf.copy()
boundaryConf[misOrienTmp<0.1] = 0
f, axarr = plt.subplots(2,2)
cf00 = axarr[0,0].imshow(conf.swapaxes(0,1),origin='lower')
f.colorbar(cf00,ax=axarr[0,0])
axarr[0,1].imshow(S.squareMicData[:,:,3].swapaxes(0,1),origin='lower')
cf10 = axarr[1,0].imshow(boundaryConf.swapaxes(0,1),origin='lower')
f.colorbar(cf10,ax=axarr[1,0])
axarr[1,1].hist(boundaryConf[boundaryConf>0])
# Out:
# (256, 3)
# 7
# voxelpos shape is (2500, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
import pickle
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
save_object((centerL, centerJ, centerK, centerRot),'geometry_run2_0.91.p')

# %%
# reconstruct sample with parameter and take the voxels at grain boundary.
# centerL = np.array([[5.55765425, 8.58272275]]) #mm
# centerJ = np.array([[1025.02723738, 1022.55610755]]) #pixel
# centerK = np.array([[2023.89012673, 2014.29526233]]) #pixel
# centerRot = np.array([[[90.0, 90.0, 0.0], [90.0, 90.0, 0.0]]])
S.set_Q(7)
S.create_square_mic([10,10],voxelsize=0.005,shift=[0,0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'Au_johnson_aug18_10x10_0.005_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 5000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)
aIdxVoxel = S.geo_opt_phase_1(centerL, centerJ, centerK, centerRot)
S.save_square_mic('geo_opt_test.npy')

plt.imshow(S.squareMicData[:,:,6].T, origin='lower')
plt.colorbar()
plt.show()
# Out:
# voxelpos shape is (100, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...

# %%
#check binary files
# check how binary files looks like
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,10)
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
b=IntBin.ReadI9BinaryFiles('/home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_{0:06d}.bin{1}'.format(int(idxRot),idxL))
plt.scatter(2047-b[0],2047-b[1],c='b',s=1)

plt.axis('scaled')
plt.xlim((0,2048))
plt.ylim((0,2048))
plt.show()

# %%
#recon
import reconstruction
import MicFileTool
import numpy as np
import matplotlib.pyplot as plt
import IntBin
import pickle
with open('geometry_run2_0.91.p', 'rb') as input:
    centerL, centerJ, centerK, centerRot  = pickle.load(input)
S = reconstruction.Reconstructor_GPU()
S.set_det_param(centerL, centerJ, centerK, centerRot)
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('iron_bcc')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/SA1_test1_reduced_1degree/SA1_test1_Iron_' # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([100,100],voxelsize=0.015,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'SA1_johnson_aug17_100x100_0.015_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000          # number of orientations search at each iteration, larger number will take longer time.
S.intensity_threshold = 50
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True
S.serial_recon_multi_stage()
# Out:
# (256, 3)
# 7
# [[-6.5999846 -2.1999948  0.       ]
#  [-6.5999846  0.        -2.1999948]
#  [-6.5999846  0.         2.1999948]
#  [-6.5999846  2.1999948  0.       ]
#  [-4.3999896 -4.3999896  0.       ]
#  [-4.3999896 -2.1999948 -2.1999948]
#  [-4.3999896 -2.1999948  2.1999948]
#  [-4.3999896  0.        -4.3999896]
#  [-4.3999896  0.         0.       ]
#  [-4.3999896  0.         4.3999896]
#  [-4.3999896  2.1999948 -2.1999948]
#  [-4.3999896  2.1999948  2.1999948]
#  [-4.3999896  4.3999896  0.       ]
#  [-2.1999948 -6.5999846  0.       ]
#  [-2.1999948 -4.3999896 -2.1999948]
#  [-2.1999948 -4.3999896  2.1999948]
#  [-2.1999948 -2.1999948 -4.3999896]
#  [-2.1999948 -2.1999948  0.       ]
#  [-2.1999948 -2.1999948  4.3999896]
#  [-2.1999948  0.        -6.5999846]
#  [-2.1999948  0.        -2.1999948]
#  [-2.1999948  0.         2.1999948]
#  [-2.1999948  0.         6.5999846]
#  [-2.1999948  2.1999948 -4.3999896]
#  [-2.1999948  2.1999948  0.       ]
# ...

# %%
plt.rcParams["figure.figsize"] = (10,10)
MicFileTool.plot_square_mic(S.squareMicData,0.18)

# %%
plt.hist(b[2],bins=100)
# Out:
# (array([3.07311e+05, 8.23250e+04, 3.73720e+04, 2.39610e+04, 1.76280e+04,
#         1.29790e+04, 9.78900e+03, 8.64200e+03, 6.56700e+03, 5.49500e+03,
#         4.84300e+03, 4.37300e+03, 3.76500e+03, 3.12100e+03, 2.55400e+03,
#         2.37800e+03, 2.06700e+03, 1.65300e+03, 1.41300e+03, 1.45700e+03,
#         1.12100e+03, 8.56000e+02, 8.43000e+02, 8.33000e+02, 6.67000e+02,
#         6.34000e+02, 5.57000e+02, 4.32000e+02, 4.26000e+02, 4.11000e+02,
#         3.10000e+02, 2.79000e+02, 2.58000e+02, 2.91000e+02, 1.77000e+02,
#         1.55000e+02, 2.13000e+02, 1.65000e+02, 1.55000e+02, 1.26000e+02,
#         6.90000e+01, 1.00000e+02, 6.10000e+01, 7.30000e+01, 5.30000e+01,
#         8.00000e+01, 6.40000e+01, 5.90000e+01, 8.50000e+01, 4.20000e+01,
#         4.10000e+01, 7.00000e+01, 2.80000e+01, 4.70000e+01, 2.10000e+01,
#         4.40000e+01, 3.00000e+01, 3.40000e+01, 2.70000e+01, 1.80000e+01,
#         1.80000e+01, 1.90000e+01, 1.70000e+01, 1.80000e+01, 1.20000e+01,
# ...

# %% [markdown]
# # Start with sample SB1_V1_Z0

# %%
#check binary files
# check how binary files looks like
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,10)
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
b=IntBin.ReadI9BinaryFiles('/home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_{0:06d}.bin{1}'.format(int(idxRot),idxL))
plt.scatter(2047-b[0],2047-b[1],c='b',s=1)

plt.axis('scaled')
plt.xlim((0,2048))
plt.ylim((0,2048))
plt.show()

# %%
# integrate binary
output='/home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_V1__z0_1degree/'
ImagePar={'nDetectors':2,
        'sBinFilePrefix':'/home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_',
        'nReductionNSUM':4,
        'nBinFileIndexStart':0,
        'fOmegaStart':-90,
        'fOmegaStop':90,
        }
IntBin.IntegrateBinFiles(ImagePar,output)
# Out:
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000001.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000002.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000003.bin0
# Writing: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_V1__z0_1degree/000000.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000004.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000005.bin0
# Reading: /home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_000006.bin0
# ...

# %%
#recon
import reconstruction
import MicFileTool
import numpy as np
import matplotlib.pyplot as plt
import IntBin
import pickle
with open('geometry_run2_0.91.p', 'rb') as input:
    centerL, centerJ, centerK, centerRot  = pickle.load(input)
S = reconstruction.Reconstructor_GPU()
S.set_det_param(centerL, centerJ, centerK, centerRot)
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('iron_bcc')
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_V1__z0_1degree/' # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([100,100],voxelsize=0.015,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'SB1_V1_Z0_johnson_aug17_100x100_0.015_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000          # number of orientations search at each iteration, larger number will take longer time.
S.intensity_threshold = 2
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True
S.serial_recon_multi_stage()
# Out:
# (256, 3)
# 7
# [[-6.5999846 -2.1999948  0.       ]
#  [-6.5999846  0.        -2.1999948]
#  [-6.5999846  0.         2.1999948]
#  [-6.5999846  2.1999948  0.       ]
#  [-4.3999896 -4.3999896  0.       ]
#  [-4.3999896 -2.1999948 -2.1999948]
#  [-4.3999896 -2.1999948  2.1999948]
#  [-4.3999896  0.        -4.3999896]
#  [-4.3999896  0.         0.       ]
#  [-4.3999896  0.         4.3999896]
#  [-4.3999896  2.1999948 -2.1999948]
#  [-4.3999896  2.1999948  2.1999948]
#  [-4.3999896  4.3999896  0.       ]
#  [-2.1999948 -6.5999846  0.       ]
#  [-2.1999948 -4.3999896 -2.1999948]
#  [-2.1999948 -4.3999896  2.1999948]
#  [-2.1999948 -2.1999948 -4.3999896]
#  [-2.1999948 -2.1999948  0.       ]
#  [-2.1999948 -2.1999948  4.3999896]
#  [-2.1999948  0.        -6.5999846]
#  [-2.1999948  0.        -2.1999948]
#  [-2.1999948  0.         2.1999948]
#  [-2.1999948  0.         6.5999846]
#  [-2.1999948  2.1999948 -4.3999896]
#  [-2.1999948  2.1999948  0.       ]
# ...

# %%
#388seconds with verbose
MicFileTool.plot_square_mic(S.squareMicData,0.48)

# %% [markdown]
# # an interesting  test to change lattice parameters

# %%
#continue optimize parameters
import reconstruction
import MicFileTool
import numpy as np
import matplotlib.pyplot as plt
import IntBin
import pickle
with open('geometry_run2_0.91.p', 'rb') as input:
    centerL, centerJ, centerK, centerRot  = pickle.load(input)
S = reconstruction.Reconstructor_GPU()
S.set_det_param(centerL, centerJ, centerK, centerRot)
S.set_Q(7)
print(S.maxQ)
S.FZFile = '/home/hedm/work/I9_test_data/Au_Mar17/DataFiles/MyFZ.dat'         # fundamental zone file
S.set_sample('iron_fcc')
S.set_lattice_constant(2.856)
S.energy = 65.351
S.expDataInitial = '/home/hedm/work/suter_aug18/johnson_aug18/SB1_postheat_restart_V1_z0_reduced/SB1_postheat_restart_V1__z0_'      # reduced binary data
S.expdataNDigit = 6                                                       # number of digit in the binary file name
S.create_square_mic([5,5],voxelsize=0.05,shift=[0.0,0.0,0])                             # resolution of reconstruction and voxel size
S.squareMicOutFile = 'SB1_V1_Z0_johnson_aug17_30x30_0.05_shift_0_0_0.npy'             # output file name
S.searchBatchSize = 6000                                                 # number of orientations search at each iteration, larger number will take longer time.
S.recon_prepare(reverseRot=True)  # at 1ID, left hand rotation needs reverseRot=True

lConst = list(np.linspace(2,3.5,150))
lConf = S.search_lattice_constant(lConst)
plt.plot(lConst, lConf)
plt.show()
# Out:
# (256, 3)
# 7
# voxelpos shape is (25, 3)
# loading det 0, rotation 0
# loading det 0, rotation 1
# loading det 0, rotation 2
# loading det 0, rotation 3
# loading det 0, rotation 4
# loading det 0, rotation 5
# loading det 0, rotation 6
# loading det 0, rotation 7
# loading det 0, rotation 8
# loading det 0, rotation 9
# loading det 0, rotation 10
# loading det 0, rotation 11
# loading det 0, rotation 12
# loading det 0, rotation 13
# loading det 0, rotation 14
# loading det 0, rotation 15
# loading det 0, rotation 16
# loading det 0, rotation 17
# loading det 0, rotation 18
# loading det 0, rotation 19
# loading det 0, rotation 20
# loading det 0, rotation 21
# loading det 0, rotation 22
# loading det 0, rotation 23
# loading det 0, rotation 24
# loading det 0, rotation 25
# loading det 0, rotation 26
# loading det 0, rotation 27
# loading det 0, rotation 28
# loading det 0, rotation 29
# loading det 0, rotation 30
# loading det 0, rotation 31
# loading det 0, rotation 32
# ...
