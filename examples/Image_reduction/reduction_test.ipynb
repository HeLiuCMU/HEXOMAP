# %% [markdown]
# # implement log segmentation
# > page 22, john lind http://www.andrew.cmu.edu/user/suter/JLind_Thesis_2013_web.pdf

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.ndimage as ndi
import glob
def median_background(initial,startIdx,outInitial, NRot=720, NDet=2,NLayer=1,layerIdx=[0],end='.tif', imgshape=[2048,2048]):
    '''
    take median over omega as background
    initial: finle name initial. e.g.:'/home/heliu/work/shahani_feb19_part/nf_part/dummy_2_rt_before_heat_nf/dummy_2_rt_before_heat_nf_'
    startIdx: idex of first imagej.
    outInitial: output initial
    NRot: number of omega interval.
    NDet: number of detector.
    NLayer: number of layer.
    layerIdx: the index used for layers
    end: file end format.
    imgshape: image resolution
    '''
    lBkg = []
    imgStack = np.empty([imgshape[0], imgshape[1], NRot],dtype=np.int32)
    start = time.time()
    for layer in range(NLayer):
        for det in range(NDet):
            for rot in range(NRot):
                idx = layer * NDet * NRot + det * NRot + rot + startIdx
                fName = f'{initial}{idx:06d}{end}'
                imgStack[:,:,rot] = plt.imread(fName)
                sys.stdout.write(f'\r {rot}')
                sys.stdout.flush()
            bkg = np.median(imgStack, axis=2)
            np.save(f'{outInitial}_z{layer}_det_{det}.npy', bkg)
            lBkg.append(bkg)
    end = time.time()
    print('\r')
    print(end - start)
    return lBkg

def segmentation(img, bkg, baseline=10, minNPixel=4):
    '''
    
    '''
    imgSub = img- bkg
    imgSubMed = ndi.median_filter(imgSub,size=2)
    imgBase = imgSubMed - baseline
    imgBase[imgBase<0] = 0
    imgBaseMedian = ndi.median_filter(imgBase, size=2)
    log = ndi.gaussian_laplace(imgBaseMedian,sigma=1.5)
    label,N = ndi.label(log<0)
    label = ndi.grey_dilation(label,size=(3,3))
    lX = []
    lY = []
    lID = []
    lIntensity = []
    start = time.time()
# fill hole??? probably not a good idea in some cases.
    for i in range(N):
        mask = (label==i)
        # fill hole??? probably not a good idea in some cases.
        #mask = ndi.binary_fill_holes(mask)
        #mask = ndi.binary_dilation(mask,iterations=2)
        vMax = np.max(imgSubMed[mask].ravel())
        if vMax > baseline:
            x, y = np.where(mask*(imgSub>max(vMax*0.1,1)))
            if x.size>minNPixel:
                for i,xx in enumerate(x):
                    lX.append(xx)
                    yy = y[i]
                    lY.append(yy)
                    lIntensity.append(imgSub[xx,yy])
                    lID.append(label[xx,yy])
    end = time.time()
    print(f'time taken:{end- start}')
    return (img.shape[1] - np.array(lY)).astype(np.int32), np.array(lX).astype(np.int32), np.array(lID).astype(np.int32), np.array(lIntensity).astype(np.int32)

def reduce_image(initial,startIdx,bkgInitial,binInitial, NRot=720, NDet=2,NLayer=1,idxLayer=[0],end='.tif', imgshape=[2048,2048],
                baseline=10, minNPixel=4):
    lBkg = median_background(initial, startIdx, bkgInitial,NRot=NRot, NDet=NDet, NLayer=NLayer,end=end)
    print('bkg images created')
    idxBkg = 0
    idxLayer = [0]
    for layer in range(NLayer):
        for det in range(NDet):
            bkg = lBkg[idxBkg]
            idxBkg += 1
            for rot in range(NRot):
                idx = layer * NDet * NRot + det * NRot + rot + startIdx
                fName = f'{initial}{idx:06d}{end}'
                img = plt.imread(fName)
                binFileName = f'{binInitial}z{idxLayer[layer]}_{rot}.bin{det}'
                print(binFileName)
                snp = segmentation(img, bkg, baseline=baseline, minNPixel=minNPixel)
                IntBin.WritePeakBinaryFile(snp, binFileName)

# %% [markdown]
# # test for back ground creation:

# %%
# test for create back ground
startIdx = 180904
NRot = 720
NDet = 1
NLayer = 1
end = '.tif'
initial = '/home/heliu/work/shahani_feb19_part/nf_part/dummy_2_rt_before_heat_nf/dummy_2_rt_before_heat_nf_'
outInitial = 'test_output_bkg'
median_background(initial, startIdx, outInitial,NRot=NRot, NDet=NDet, NLayer=NLayer,end=end)
# Out:
#  719
# 57.68604302406311
# [array([[15. , 13. , 14.5, ..., 17. , 17. , 17. ],
#         [15. , 15. , 15. , ..., 17. , 17. , 17. ],
#         [13. , 15. , 15. , ..., 17. , 17. , 17. ],
#         ...,
#         [11. , 11. , 10. , ..., 13. , 13. , 13. ],
#         [11. , 11. , 11. , ..., 13. , 13. , 14. ],
#         [12. , 11. , 11. , ..., 13. , 13. , 14. ]])]

# %%
# reduce a layer of images together:
import IntBin
import time
startIdx = 180904
NRot = 720
NDet = 1
NLayer = 1
end = '.tif'
initial = '/home/heliu/work/shahani_feb19_part/nf_part/dummy_2_rt_before_heat_nf/dummy_2_rt_before_heat_nf_'
bkgInitial = 'test_output_bkg'
binInitial = 'dummy_2_rt_before_heat_nf_test_'
reduce_image(initial,startIdx,bkgInitial,binInitial, NRot=720, NDet=2,NLayer=1,idxLayer=[0],end='.tif', imgshape=[2048,2048],
                baseline=10, minNPixel=4)
# lBkg = median_background(initial, startIdx, outInitial,NRot=NRot, NDet=NDet, NLayer=NLayer,end=end)
# print('bkg images created')
# idxBkg = 0
# idxLayer = [0]
# for layer in range(NLayer):
#     for det in range(NDet):
#         bkg = lBkg[idxBkg]
#         idxBkg += 1
#         for rot in range(NRot):
#             idx = layer * NDet * NRot + det * NRot + rot + startIdx
#             fName = f'{initial}{idx:06d}{end}'
#             img = plt.imread(fName)
#             binFileName = f'{initial}z{idxLayer[layer]}_{rot}.bin{det}'
#             print(binFileName)
#             snp = segmentation(img, bkg, baseline=10, minNPixel=4)
#             IntBin.WritePeakBinaryFile(snp, binFileName)
# Out:
#  719
# 112.08388185501099
# bkg images created
# dummy_2_rt_before_heat_nf_test_z0_0.bin0
# time taken:1.5669772624969482
# dummy_2_rt_before_heat_nf_test_z0_1.bin0
# time taken:1.5929081439971924
# dummy_2_rt_before_heat_nf_test_z0_2.bin0
# time taken:1.3424546718597412
# dummy_2_rt_before_heat_nf_test_z0_3.bin0
# time taken:2.372318744659424
# dummy_2_rt_before_heat_nf_test_z0_4.bin0
# time taken:1.5460660457611084
# dummy_2_rt_before_heat_nf_test_z0_5.bin0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-ce160f44f770> in <module>
#      11 binInitial = 'dummy_2_rt_before_heat_nf_test_'
#      12 reduce_image(initial,startIdx,bkgInitial,binInitial, NRot=720, NDet=2,NLayer=1,idxLayer=[0],end='.tif', imgshape=[2048,2048],
# ---> 13                 baseline=10, minNPixel=4)
#      14 # lBkg = median_background(initial, startIdx, outInitial,NRot=NRot, NDet=NDet, NLayer=NLayer,end=end)
#      15 # print('bkg images created')
#
# <ipython-input-26-9af919670dd3> in reduce_image(initial, startIdx, bkgInitial, binInitial, NRot, NDet, NLayer, idxLayer, end, imgshape, baseline, minNPixel)
#      88                 binFileName = f'{binInitial}z{idxLayer[layer]}_{rot}.bin{det}'
#      89                 print(binFileName)
# ---> 90                 snp = segmentation(img, bkg, baseline=baseline, minNPixel=minNPixel)
#      91                 IntBin.WritePeakBinaryFile(snp, binFileName)
#
# <ipython-input-26-9af919670dd3> in segmentation(img, bkg, baseline, minNPixel)
#      60         vMax = np.max(imgSubMed[mask].ravel())
#      61         if vMax > baseline:
# ---> 62             x, y = np.where(mask*(imgSub>max(vMax*0.1,1)))
#      63             if x.size>minNPixel:
#      64                 for i,xx in enumerate(x):
#
# KeyboardInterrupt:

# %%
import sys
sys.path.insert(0, '/home/heliu/work/dev/HEXOMAP/')
import IntBin
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (10,10)

# images
startIdx = 180904
NRot = 720
NDet = 1
NLayer = 1
end = '.tif'
binInitial = 'dummy_2_rt_before_heat_nf_test_'
fName = f'{initial}{startIdx:06d}{end}'
img = plt.imread(fName)
bkg = np.load('test_output_bkg_z0_det_0.npy')
imgDisp = img-bkg
imgDisp[imgDisp<0] = 0
##################### ice nine result #########################33
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
layer=0
b=IntBin.ReadI9BinaryFiles(f'{binInitial}z{layer}_{int(idxRot)}.bin{idxL}')
print(b[0],b[1])
fig,ax = plt.subplots(1,2)

ax[0].scatter(2047-b[0],2047 - b[1],c='r',s=1,alpha=1.0)
ax[0].imshow(imgDisp[::-1],vmin=0,vmax=20)
ax[0].axis('scaled')
ax[0].set_xlim((0,2048))
ax[0].set_ylim((0,2048))
# Out:
# [2011 1213  645 ...  599  596  595] [  16   41   91 ... 2005 2005 2006]
# <img src="data:image/png;base64,..." width="1000">
# (0, 2048)

# %%
import numpy as np
bkg = np.load('test_output_bkg_z0_det_0.npy')
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(bkg,vmin=0,vmax=100)
plt.show()

# %% [markdown]
# # test for zero cross log:

# %%
startIdx = 180904
NRot = 720
NDet = 1
NLayer = 1
end = '.tif'
initial = '/home/heliu/work/shahani_feb19_part/nf_part/dummy_2_rt_before_heat_nf/dummy_2_rt_before_heat_nf_'
fName = f'{initial}{startIdx:06d}{end}'

img = plt.imread(fName)
bkg = np.load('test_output_bkg_z0_det_0.npy')
imgSub = img- bkg
imgSubMed = ndi.median_filter(imgSub,size=3)

# plt.imshow(img,vmin=0,vmax=50)
# plt.show()
# plt.imshow(imgSub,vmin=0,vmax=10)
# plt.show()
# plt.imshow(imgSubMed,vmin=10,vmax=20)
# plt.show()

# %%
# %matplotlib inline
imgBase = imgSubMed - 10
imgBase[imgBase<0] = 0
log = ndi.gaussian_laplace(imgBase,sigma=0.75)
logMedian = ndi.median_filter(log, size=3)
label,N = ndi.label(log<0)
lX = []
lY = []
lID = []
lIntensity = []
start = time.time()
for i in range(N):
    label
    vMax = np.max(imgBase[label==i].ravel())
    if vMax > 0:
        x, y = np.where((label==i)*(imgBase>vMax*0.1))
        for i,xx in enumerate(x):
            lX.append(xx)
            yy = y[i]
            lY.append(yy)
            lIntensity.append(imgBase[xx,yy])
            lID.append(label[xx,yy])
end = time.time()
print(f'time taken:{end- start}')
plt.imshow(log,vmin=0,vmax=50)
plt.show()
plt.imshow(imgBase,vmin=0,vmax=10)
plt.show()
print(N)
# Out:
# time taken:2.0831196308135986
# 136

# %%
import sys
sys.path.insert(0, '/home/heliu/work/dev/HEXOMAP/')
import IntBin
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (10,10)
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
b=IntBin.ReadI9BinaryFiles('/home/yufengs/shahani19/dummy_2_before_heat_reduced/dummy_2_z0_{0:06d}.bin{1}'.format(int(idxRot),idxL))

fig,ax = plt.subplots(1,2)
ax[0].imshow(imgSubMed,vmin=0,vmax=20)
ax[0].scatter(2047-b[0],b[1],c='r',s=1,alpha=0.5)
ax[0].axis('scaled')
ax[0].set_xlim((0,2048))
ax[0].set_ylim((0,2048))

ax[1].imshow(imgSubMed,vmin=0,vmax=20)
ax[1].scatter(lY,np.array(lX),c='r',s=1,alpha=0.5)
ax[1].axis('scaled')
ax[1].set_xlim([0, 2048])
ax[1].set_ylim([0, 2048])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib notebook
plt.imshow((imgBase>0)*label,vmin=0,vmax=10)
plt.show()
print(N)
# Out:
# <img src="data:image/png;base64,..." width="1080">
# 55

# %%
# %matplotlib notebook
plt.imshow(log,vmin=-5,vmax=5)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
plt.imshow(logMedian,vmin=-1,vmax=5)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1080">

# %%
import numpy as np
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
import time
# %matplotlib notebook
def segmentation(img, bkg, baseline=10, minNPixel=4):
    '''
    baseline: signal fluctuation, may need to change according to exposure time?
    minNPixel: number of pixel limit
    '''
    imgSub = img- bkg
    imgSubMed = ndi.median_filter(imgSub,size=2)
    imgBase = imgSub - baseline
    imgBase[imgBase<0] = 0
    imgBaseMedian = ndi.median_filter(imgBase,size=2)
    log = ndi.gaussian_laplace(imgBaseMedian,sigma=1.5)
    #logMedian = ndi.median_filter(log, size=3)
    label,N = ndi.label(log<0)
    label = ndi.grey_dilation(label,size=(3,3))
    lX = []
    lY = []
    lID = []
    lIntensity = []
    start = time.time()
# fill hole??? probably not a good idea in some cases.
    print(N)
    for i in range(N):
        sys.stdout.write(f'\r {i}')
        sys.stdout.flush()
        mask = (label==i)
        #mask = ndi.binary_dilation(mask,iterations=2)
        # fill hole??? probably not a good idea in some cases.
        #mask = ndi.binary_fill_holes(mask)
        #vMax = np.max(imgSubMed[mask].ravel())
        x, y = np.where(mask)
        v = imgSubMed[x, y]
        vMax = max(v)
        if vMax > baseline:
            #x, y = np.where(mask*(imgSubMed>vMax*0.1))
            aIdx = np.where(v>(vMax*0.1))[0]
            #print(aIdx)
            if aIdx.size>minNPixel:
                for idx in aIdx:
                    lX.append(x[idx])
                    lY.append(y[idx])
                    lIntensity.append(v[idx])
                    lID.append(i)
    end = time.time()
    print(f'time taken:{end- start}')
    return lX, lY, lID, lIntensity


import sys
sys.path.insert(0, '/home/heliu/work/dev/HEXOMAP/')
import IntBin
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (10,10)

# images

pr.disable()
s = io.StringIO()
sortby = SortKey.CUMULATIVE
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())


##################### ice nine result #########################33
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
b=IntBin.ReadI9BinaryFiles('/home/yufengs/shahani19/dummy_2_before_heat_reduced/dummy_2_z0_{0:06d}.bin{1}'.format(int(idxRot),idxL))
fig,ax = plt.subplots(1,2)
ax[0].imshow(imgDisp,vmin=0,vmax=20)
ax[0].scatter(2047-b[0],b[1],c='r',s=1,alpha=1.0)
ax[0].axis('scaled')
ax[0].set_xlim((0,2048))
ax[0].set_ylim((0,2048))

################### python result #################################
ax[1].imshow(imgDisp,vmin=0,vmax=20)
ax[1].scatter(lY,np.array(lX),c='r',s=1,alpha=1.0)
ax[1].axis('scaled')
ax[1].set_xlim([0, 2048])
ax[1].set_ylim([0, 2048])
plt.show()
# Out:
# 125
#  124time taken:1.9309310913085938
#          50254 function calls in 2.551 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    2.551    1.276 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3228(run_code)
#         2    0.000    0.000    2.551    1.276 {built-in method builtins.exec}
#         1    0.009    0.009    2.551    2.551 <ipython-input-4-6775a9f1d12e>:78(<module>)
#         1    0.302    0.302    2.542    2.542 <ipython-input-4-6775a9f1d12e>:6(segmentation)
#       252    1.184    0.005    1.184    0.005 {built-in method numpy.core.multiarray.where}
#       189    0.383    0.002    0.383    0.002 {built-in method builtins.max}
#         2    0.000    0.000    0.301    0.151 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:1189(median_filter)
#         2    0.000    0.000    0.301    0.151 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:1094(_rank_filter)
#         2    0.301    0.151    0.301    0.151 {built-in method scipy.ndimage._nd_image.rank_filter}
#         1    0.002    0.002    0.194    0.194 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:439(gaussian_laplace)
#         1    0.003    0.003    0.192    0.192 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:367(generic_laplace)
#         2    0.000    0.000    0.189    0.095 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:476(derivative2)
#         2    0.000    0.000    0.189    0.095 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:207(gaussian_filter)
#         4    0.000    0.000    0.189    0.047 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:154(gaussian_filter1d)
#         4    0.000    0.000    0.187    0.047 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:52(correlate1d)
#         4    0.187    0.047    0.187    0.047 {built-in method scipy.ndimage._nd_image.correlate1d}
#       125    0.001    0.000    0.087    0.001 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:334(flush)
#       125    0.001    0.000    0.083    0.001 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:534(wait)
#       125    0.001    0.000    0.082    0.001 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:264(wait)
#      1130    0.081    0.000    0.081    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.062    0.062 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/morphology.py:1213(grey_dilation)
#         1    0.000    0.000    0.062    0.062 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:953(_min_or_max_filter)
#         2    0.000    0.000    0.062    0.031 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:896(maximum_filter1d)
#         2    0.062    0.031    0.062    0.031 {built-in method scipy.ndimage._nd_image.min_or_max_filter1d}
#         1    0.000    0.000    0.020    0.020 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/measurements.py:46(label)
#         1    0.020    0.020    0.020    0.020 {built-in method scipy.ndimage._ni_label._label}
#       505    0.001    0.000    0.007    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:195(schedule)
#       129    0.001    0.000    0.007    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:382(write)
#       505    0.003    0.000    0.003    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/zmq/sugar/socket.py:334(send)
#       630    0.001    0.000    0.002    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:1080(is_alive)
#         4    0.000    0.000    0.002    0.001 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:133(_gaussian_kernel1d)
#       129    0.000    0.000    0.002    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:320(_schedule_flush)
#     40140    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       630    0.001    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:1038(_wait_for_tstate_lock)
#       125    0.000    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:499(__init__)
#        56    0.000    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:124(as_series)
#        20    0.000    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:246(__init__)
#       125    0.001    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:216(__init__)
#         6    0.000    0.000    0.001    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:649(deriv)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:325(__mul__)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:309(__add__)
#       129    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:307(_is_master_process)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:290(__call__)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polynomial.py:479(polyder)
#       169    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#       505    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/ipykernel/iostream.py:93(_event_pipe)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/_ni_support.py:71(_get_output)
#       125    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:252(_acquire_restore)
#        13    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#       630    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:507(is_set)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polynomial.py:333(polymul)
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/lib/type_check.py:580(common_type)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1524(moveaxis)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polynomial.py:688(polyval)
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:182(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:174(<listcomp>)
#         8    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:210(_get_coefficients)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polynomial.py:207(polyadd)
#        24    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       129    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:196(<listcomp>)
#       125    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:243(__exit__)
#        17    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2016(all)
#       125    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:240(__enter__)
#       250    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       630    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/morphology.py:124(generate_binary_structure)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/codeop.py:132(__call__)
#       125    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:255(_is_owned)
#         6    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       125    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/threading.py:249(_release_save)
#        24    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1468(normalize_axis_tuple)
#        17    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:64(_wrapreduction)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/_methods.py:34(_sum)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       181    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        24    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:94(trimseq)
#        74    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/lib/type_check.py:250(iscomplexobj)
#        20    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:433(asarray)
#        15    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/_ni_support.py:55(_normalize_sequence)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1800(indices)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:300(mapparms)
#         8    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:180(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:950(convolve)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:156(ones)
#       125    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#       125    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#       125    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       213    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/_polybase.py:587(mapparms)
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1927(isscalar)
#       138    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         8    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.copyto}
#       125    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        48    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1515(<genexpr>)
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:175(<listcomp>)
#        56    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polyutils.py:177(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.correlate}
#        15    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:876(_mode_from_name)
#        50    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#         8    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/_ni_support.py:38(_extend_mode_to_code)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/abc.py:137(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/IPython/core/hooks.py:142(__call__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-4-6775a9f1d12e>:79(<module>)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/polynomial/polynomial.py:536(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:504(asanyarray)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:1110(<listcomp>)
#        12    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/core/numeric.py:1586(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:281(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/_ni_support.py:86(_check_axis)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        24    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/scipy/ndimage/filters.py:988(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/numpy/lib/index_tricks.py:656(__getitem__)
#         4    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/IPython/core/hooks.py:207(pre_run_code_hook)
#         2    0.000    0.000    0.000    0.000 /opt/anaconda/anaconda3/envs/pycuda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:1256(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# <img src="data:image/png;base64,..." width="1000">

# %%
import numpy as np
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
import time
# %matplotlib notebook
def segmentation(img, bkg, minNPixel=4):
    '''
    
    '''
    imgSub = img- bkg
    imgSubMed = ndi.median_filter(imgSub,size=2)
    imgBase = imgSubMed - 10
    imgBase[imgBase<0] = 0
    imgBaseMedian = ndi.median_filter(imgBase, size=2)
    log = ndi.gaussian_laplace(imgBaseMedian,sigma=1.5)
    label,N = ndi.label(log<0)
    label = ndi.grey_dilation(label,size=(3,3))
    lX = []
    lY = []
    lID = []
    lIntensity = []
    start = time.time()
# fill hole??? probably not a good idea in some cases.
    for i in range(N):
        mask = (label==i)
        # fill hole??? probably not a good idea in some cases.
        #mask = ndi.binary_fill_holes(mask)
        #mask = ndi.binary_dilation(mask,iterations=2)
        vMax = np.max(imgSubMed[mask].ravel())
        if vMax > 10:
            x, y = np.where(mask*(imgSub>max(vMax*0.1,1)))
            if x.size>minNPixel:
                for i,xx in enumerate(x):
                    lX.append(xx)
                    yy = y[i]
                    lY.append(yy)
                    lIntensity.append(imgSub[xx,yy])
                    lID.append(label[xx,yy])
    end = time.time()
    print(f'time taken:{end- start}')
    return lX, lY, lID, lIntensity



import sys
sys.path.insert(0, '/home/heliu/work/dev/HEXOMAP/')
import IntBin
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (10,10)

# images
startIdx = 180904
NRot = 720
NDet = 1
NLayer = 1
end = '.tif'
initial = '/home/heliu/work/shahani_feb19_part/nf_part/dummy_2_rt_before_heat_nf/dummy_2_rt_before_heat_nf_'
fName = f'{initial}{startIdx:06d}{end}'
img = plt.imread(fName)
bkg = np.load('test_output_bkg_z0_det_0.npy')
imgDisp = img-bkg
imgDisp[imgDisp<0] = 0

lX, lY, lIntensity, lID = segmentation(img, bkg)

##################### ice nine result #########################33
idxRot = 0  # index of rotation (0~719)
idxL = 0    # index of detector distance(0~2)
b=IntBin.ReadI9BinaryFiles('/home/yufengs/shahani19/dummy_2_before_heat_reduced/dummy_2_z0_{0:06d}.bin{1}'.format(int(idxRot),idxL))
fig,ax = plt.subplots(1,2)
ax[0].imshow(imgDisp,vmin=0,vmax=20)
ax[0].scatter(2047-b[0],b[1],c='r',s=1,alpha=1.0)
ax[0].axis('scaled')
ax[0].set_xlim((0,2048))
ax[0].set_ylim((0,2048))

################### python result #################################
ax[1].imshow(imgDisp,vmin=0,vmax=20)
ax[1].scatter(lY,np.array(lX),c='r',s=1,alpha=1.0)
ax[1].axis('scaled')
ax[1].set_xlim([0, 2048])
ax[1].set_ylim([0, 2048])
plt.show()
# Out:
# time taken:1.698519229888916
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # john's psudo code:
#
# 1. subtract background
#
# 1. subtract baseline
#
# 1. median filter
#
# 1. label
#
# 1. get minimum and maximum of each label
#
# 1. for each peak i:
#
#     - mTimes=median*mask_of_label_i
#
#     - log_filter_2(mTimes, sigma=1)
#
#     - f2i = (float)(zfilt(mTimes))  ( zerocrossing, one pixel thick lines, then float to int)
#
#         --var_array[0] = 0.5;//sigma_x of gaussian
#
#         --var_array[1] = 1.0;//sigma_y of gaussian
#
#     - BinMaskCreator = (median>=0)
#
#     - ImDilateBinMask = dilate(BinMaskCreator,radius=0.65)
#
#     - zTimes( f2i, ImDilateBinMask) ( multiply)
#
#     - ImDilate_zTimes(zTimes, radius=1)
#
#     - BarrierMask = (log_filt_2<=0)
#
#     - LBarrier = dilate(BarrierMask, 1)
#
#     - PoolMask = (log_filt_1 <= -1)
#
#     - LPool = dilate(PoolMask, 1)
#
#     - mPoolxBarrier = LPoor * LBarrier
#
#     - LPool = dilate(mPoolxBarrier, 1)
#
#         - floodfill(LPool)
#
#     - PeakMask = flood_fill(L_pool,)
